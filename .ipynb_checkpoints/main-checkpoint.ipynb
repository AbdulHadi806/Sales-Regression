# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %matplotlib inline
sns.set(color_codes=True)

# %%
df = pd.read_csv('sales_data_sample.csv', encoding='latin1')
print(df.shape, ' :data shape')
df.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df = pd.read_csv('sales_data_sample.csv')
#       2 print(df.shape, ' :data shape')
#       3 df.head()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
# converting time into numbers cause computer loves numbers
df["timestamp"] = pd.to_datetime(df["timestamp"])
df['year'] = df['timestamp'].dt.year
df['month'] = df['timestamp'].dt.month

# %%
df.head()
# Out:
#    timestamp  profit  marketing_budget  developers_hired  bugs_fixed  \
# 0 2014-01-01     300              2000                 2         300
# 1 2014-02-01     350              2100                 3         350
# 2 2014-03-01     400              2200                 4         400
# 3 2014-04-01     450              2300                 5         450
# 4 2014-05-01     500              2400                 6         500
#
#    website_visits technology_status  year  month
# 0            5000            famous  2014      1
# 1            5500            famous  2014      2
# 2            6000            famous  2014      3
# 3            6500            famous  2014      4
# 4            7000            famous  2014      5

# %%
# droping timestamp
df.drop('timestamp', axis=1, inplace = True)

# %%
df.shape
# Out:
# (120, 8)

# %%
df.dtypes
# Out:
# profit                int64
# marketing_budget      int64
# developers_hired      int64
# bugs_fixed            int64
# website_visits        int64
# technology_status    object
# year                  int32
# month                 int32
# dtype: object

# %%
# Converting departement into usable form
df["technology_status"] = df["technology_status"].astype('category')
technology_status = pd.get_dummies(df["technology_status"], drop_first = True)
df = pd.concat((df, technology_status), axis=1)

# %%
df.head()
# Out:
#    profit  marketing_budget  developers_hired  bugs_fixed  website_visits  \
# 0     300              2000                 2         300            5000
# 1     350              2100                 3         350            5500
# 2     400              2200                 4         400            6000
# 3     450              2300                 5         450            6500
# 4     500              2400                 6         500            7000
#
#   technology_status  year  month  outdated
# 0            famous  2014      1     False
# 1            famous  2014      2     False
# 2            famous  2014      3     False
# 3            famous  2014      4     False
# 4            famous  2014      5     False

# %%
# Droping department label now :)
df.drop('technology_status', axis=1, inplace=True)

# %%
df.shape
# Out:
# (120, 8)

# %%
# Checking if there are any missing values
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap="tab20_r")
plt.title("Missing Data")
plt.show()
# So no missing value atleast half work is already done. Thank God

# %%
onlyNumbers = df.select_dtypes(include=['number'])
Q1 = onlyNumbers.quantile(0.25)
Q3 = onlyNumbers.quantile(0.75)
IQR = Q3-Q1
print('IQR', IQR)
# The IQR looks good to me...
# Out:
# IQR profit               1000.0
# marketing_budget    11900.0
# developers_hired       59.5
# bugs_fixed           2975.0
# website_visits      29750.0
# year                    5.0
# month                   5.5
# dtype: float64

# %%
# Now almost there, EDA is almost done
df.dtypes
# Out:
# profit              int64
# marketing_budget    int64
# developers_hired    int64
# bugs_fixed          int64
# website_visits      int64
# year                int32
# month               int32
# outdated             bool
# dtype: object

# %%
# checking correlation for final show down
# df = df.drop(columns=["marketing_spend", "year", "Sales"], inplace=False)
correlation = df.corr()

# %%
plt.figure(figsize=(10, 5))
sns.heatmap(correlation, cmap="BrBG", annot = True)
plt.show()

# %%
# Weak correlation with profit
df.drop("month", axis=1, inplace=True)

# %%
df.drop("outdated", axis=1, inplace=True)

# %%
X = df.drop("profit", axis = 1)
y = df["profit"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
print(y_pred)
# Out:
# [1083.13514541 1763.27478899 1782.06086741 1682.15583909 1763.86643355
#   195.10715946 1782.65251197 1714.01628845 1800.25530127 1713.42464389
#  1780.28593373 1712.83299933 1764.45807811 1797.88872303 1307.76790554
#  1799.07201215 1762.68314443 1692.86363179 1711.05806565 1697.59678827
#  1767.41630091 1816.67480145 1815.49151233 1691.08869811]

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print('Mean Squared Error:', mse)
print('R-squared Score:', r2)
# Out:
# Mean Squared Error: 171858.1504433313
# R-squared Score: 0.41063172984425567

# %%
sns.displot(df["profit"], kde=True, rug=True)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
